# %% [markdown]
# # Welcome to Jupytermux
#
# This is a sample Jupyter notebook running on your Android device.
#
# ## Features
#
# - View Jupyter notebooks
# - Execute Python code
# - Access terminal commands
# - Manage files directly from your phone

# %%
# Python Code Cell
import math

# Calculate circle area
radius = 5
area = math.pi * radius ** 2
print(f'Circle area with radius {radius}: {area:.2f}')

# %%
# Data manipulation example
data = [1, 2, 3, 4, 5]
result = sum(data) / len(data)
print(f'Average: {result}')

# %% [markdown]
# ## Getting Started
#
# 1. Open a notebook from your device
# 2. Switch to the Terminal tab for shell access
# 3. Edit and execute code cells
# 4. Save your work
